# %%
# https://en.wikipedia.org/wiki/List_of_counties_in_California

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, matplotlib.cm as cm
from matplotlib.collections import PatchCollection
from descartes import PolygonPatch
from shapely.geometry import Polygon, MultiPolygon
# %matplotlib inline

# %%
lodes_filepath = 'ca_od_main_JT00_2015.csv'

def load_str(value):
    return str(value)
converters = {'w_geocode' : load_str,
              'h_geocode' : load_str}

# load the lodes data and preserve fips codes as strings bc of preceding zeros
lodes = pd.read_csv(lodes_filepath, converters=converters)

# %%
lodes.columns
# Out:
# Index(['w_geocode', 'h_geocode', 'S000', 'SA01', 'SA02', 'SA03', 'SE01',
#        'SE02', 'SE03', 'SI01', 'SI02', 'SI03', 'createdate'],
#       dtype='object')

# %%
lodes['h_geocode'] = lodes['h_geocode'].apply(int)
lodes['w_geocode'] = lodes['w_geocode'].apply(int)

# %%
lodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14713690 entries, 0 to 14713689
# Data columns (total 13 columns):
# w_geocode     int64
# h_geocode     int64
# S000          int64
# SA01          int64
# SA02          int64
# SA03          int64
# SE01          int64
# SE02          int64
# SE03          int64
# SI01          int64
# SI02          int64
# SI03          int64
# createdate    int64
# dtypes: int64(13)
# memory usage: 1.4 GB

# %%
lodes['w_geocode'] = lodes['w_geocode'].apply(int)
lodes['h_geocode'] = lodes['h_geocode'].apply(int)

# %%
lodes.head()
# Out:
#          w_geocode        h_geocode  S000  SA01  SA02  SA03  SE01  SE02  SE03  \
# 0  060014001001007  060014003004007     1     0     1     0     0     0     1
# 1  060014001001007  060014027002024     1     1     0     0     0     0     1
# 2  060014001001007  060014037011000     1     0     1     0     0     0     1
# 3  060014001001007  060014042001011     1     0     1     0     0     0     1
# 4  060014001001007  060014042003000     1     0     1     0     0     0     1
#
#    SI01  SI02  SI03  createdate
# 0     0     0     1    20190826
# 1     0     0     1    20190826
# 2     0     0     1    20190826
# 3     0     0     1    20190826
# 4     0     0     1    20190826

# %% [markdown]
# ## Determine which census tracts have the highest number of jobs that people commute to from another county.

# %%
# load crosswalk table to join by
cxwalk = pd.read_csv("ca_xwalk.csv", encoding="ISO-8859-1", low_memory=False)

# %%
cxwalk.head()
# Out:
#        tabblk2010  st stusps      stname   cty            ctyname        trct  \
# 0  60971502032017   6     CA  California  6097  Sonoma County, CA  6097150203
# 1  60971502024011   6     CA  California  6097  Sonoma County, CA  6097150202
# 2  60971502021001   6     CA  California  6097  Sonoma County, CA  6097150202
# 3  60971502023008   6     CA  California  6097  Sonoma County, CA  6097150202
# 4  60971502041022   6     CA  California  6097  Sonoma County, CA  6097150204
#
#                trctname         bgrp                       bgrpname  ...  \
# 0  1502.03 (Sonoma, CA)  60971502032  2 (Tract 1502.03, Sonoma, CA)  ...
# 1  1502.02 (Sonoma, CA)  60971502024  4 (Tract 1502.02, Sonoma, CA)  ...
# 2  1502.02 (Sonoma, CA)  60971502021  1 (Tract 1502.02, Sonoma, CA)  ...
# 3  1502.02 (Sonoma, CA)  60971502023  3 (Tract 1502.02, Sonoma, CA)  ...
# 4  1502.04 (Sonoma, CA)  60971502041  1 (Tract 1502.04, Sonoma, CA)  ...
#
#    stanrcname  necta  nectaname  mil  milname    stwib             stwibname  \
# 0         NaN  99999        NaN  NaN      NaN  6000056  56 Sonoma County WIB
# 1         NaN  99999        NaN  NaN      NaN  6000056  56 Sonoma County WIB
# 2         NaN  99999        NaN  NaN      NaN  6000056  56 Sonoma County WIB
# 3         NaN  99999        NaN  NaN      NaN  6000056  56 Sonoma County WIB
# 4         NaN  99999        NaN  NaN      NaN  6000056  56 Sonoma County WIB
#
#     blklatdd    blklondd createdate
# 0  38.276402 -122.450695   20190826
# 1  38.302804 -122.465186   20190826
# 2  38.308897 -122.446649   20190826
# 3  38.293432 -122.441744   20190826
# 4  38.284894 -122.451305   20190826
#
# [5 rows x 43 columns]

# %%
# sf bay area counties to filter on
cty_fips_list = [6001, 6013, 6041, 6055, 6075, 6081, 6085, 6095, 6097]

# %%
# filter rows in crosswalk to include only SF Bay counties and fields we need
cxwalk = cxwalk[cxwalk['cty'].isin(cty_fips_list)]
cxwalk = cxwalk[['trct', 'tabblk2010', 'cty', 'ctyname']]

# %%
# perform an inner join on crosswalk data and origin destination data to keep only blocks for SF Bay Area
data_w = lodes.merge(cxwalk, how="inner", left_on="w_geocode", right_on="tabblk2010")

# %%
# create seperate home and work county fips columns as strings to compare with one another
data_w['cty_h'] = data_w['h_geocode'].apply(str).str.slice(0,4)
data_w['cty_w'] = data_w['w_geocode'].apply(str).str.slice(0,4)
data_w
# Out:
#               w_geocode       h_geocode  S000  SA01  SA02  SA03  SE01  SE02  \
# 0        60014001001007  60014003004007     1     0     1     0     0     0
# 1        60014001001007  60014027002024     1     1     0     0     0     0
# 2        60014001001007  60014037011000     1     0     1     0     0     0
# 3        60014001001007  60014042001011     1     0     1     0     0     0
# 4        60014001001007  60014042003000     1     0     1     0     0     0
# ...                 ...             ...   ...   ...   ...   ...   ...   ...
# 3432928  60971543043130  60971543043108     1     0     0     1     0     0
# 3432929  60971543043130  61150410005040     1     0     1     0     0     1
# 3432930  60971543043138  60971530022000     1     0     1     0     0     1
# 3432931  60971543043138  60971537043012     1     0     1     0     1     0
# 3432932  60971543043138  60971537044005     1     0     1     0     1     0
#
#          SE03  SI01  SI02  SI03  createdate        trct      tabblk2010   cty  \
# 0           1     0     0     1    20190826  6001400100  60014001001007  6001
# 1           1     0     0     1    20190826  6001400100  60014001001007  6001
# 2           1     0     0     1    20190826  6001400100  60014001001007  6001
# 3           1     0     0     1    20190826  6001400100  60014001001007  6001
# 4           1     0     0     1    20190826  6001400100  60014001001007  6001
# ...       ...   ...   ...   ...         ...         ...             ...   ...
# 3432928     1     0     0     1    20190826  6097154304  60971543043130  6097
# 3432929     0     0     0     1    20190826  6097154304  60971543043130  6097
# 3432930     0     0     0     1    20190826  6097154304  60971543043138  6097
# 3432931     0     0     0     1    20190826  6097154304  60971543043138  6097
# 3432932     0     0     0     1    20190826  6097154304  60971543043138  6097
#
#                     ctyname cty_h cty_w
# 0        Alameda County, CA  6001  6001
# 1        Alameda County, CA  6001  6001
# 2        Alameda County, CA  6001  6001
# 3        Alameda County, CA  6001  6001
# 4        Alameda County, CA  6001  6001
# ...                     ...   ...   ...
# 3432928   Sonoma County, CA  6097  6097
# 3432929   Sonoma County, CA  6115  6097
# 3432930   Sonoma County, CA  6097  6097
# 3432931   Sonoma County, CA  6097  6097
# 3432932   Sonoma County, CA  6097  6097
#
# [3432933 rows x 19 columns]

# %%
# filter od blocks to those that have different work and home county fips
data_w_filtered = data_w[(data_w['cty_h'] != data_w['cty_w'])]

# %%
# inspect data
data_w_filtered.head(10)
# Out:
#         w_geocode        h_geocode  S000  SA01  SA02  SA03  SE01  SE02  SE03  \
# 0  60014001001007  060014003004007     1     0     1     0     0     0     1
# 1  60014001001007  060014027002024     1     1     0     0     0     0     1
# 2  60014001001007  060014037011000     1     0     1     0     0     0     1
# 3  60014001001007  060014042001011     1     0     1     0     0     0     1
# 4  60014001001007  060014042003000     1     0     1     0     0     0     1
# 5  60014001001007  060014042003004     1     0     1     0     0     0     1
# 6  60014001001007  060014045023003     1     0     0     1     0     0     1
# 7  60014001001007  060014046001000     1     0     0     1     0     0     1
# 8  60014001001007  060014046001009     1     0     0     1     0     0     1
# 9  60014001001007  060014049003007     1     0     1     0     0     0     1
#
#    SI01  SI02  SI03  createdate        trct      tabblk2010   cty  \
# 0     0     0     1    20190826  6001400100  60014001001007  6001
# 1     0     0     1    20190826  6001400100  60014001001007  6001
# 2     0     0     1    20190826  6001400100  60014001001007  6001
# 3     0     0     1    20190826  6001400100  60014001001007  6001
# 4     0     0     1    20190826  6001400100  60014001001007  6001
# 5     0     0     1    20190826  6001400100  60014001001007  6001
# 6     0     0     1    20190826  6001400100  60014001001007  6001
# 7     0     0     1    20190826  6001400100  60014001001007  6001
# 8     0     0     1    20190826  6001400100  60014001001007  6001
# 9     0     0     1    20190826  6001400100  60014001001007  6001
#
#               ctyname cty_h cty_w
# 0  Alameda County, CA  0600  6001
# 1  Alameda County, CA  0600  6001
# 2  Alameda County, CA  0600  6001
# 3  Alameda County, CA  0600  6001
# 4  Alameda County, CA  0600  6001
# 5  Alameda County, CA  0600  6001
# 6  Alameda County, CA  0600  6001
# 7  Alameda County, CA  0600  6001
# 8  Alameda County, CA  0600  6001
# 9  Alameda County, CA  0600  6001

# %%
# aggregate blocks to tracts and sum S000 column
data_agg = data_w_filtered.groupby(['trct', 'cty'], as_index=False)[['S000']].sum()

# %%
# sort by S000 column descending
data_agg = data_agg.sort_values('S000', ascending=False)

# %%
# inspect the data
data_agg.head(10)
# Out:
#             trct   cty   S000
# 850   6075061500  6075  83356
# 674   6075011700  6075  67945
# 270   6001441503  6001  42289
# 884   6081602300  6081  24844
# 1175  6085505006  6085  24833
# 725   6075017601  6075  24001
# 1319  6085511705  6085  20124
# 726   6075017700  6075  19461
# 665   6075010500  6075  17851
# 1167  6085504602  6085  15550

# %%
dirname = os.path.dirname(os.path.realpath("__file__"))
dirname
# Out:
# 'C:\\Users\\SIDDHARTH\\OneDrive\\Documents'

# %%
# write processed data to csv file
import sys, os
outfile = os.path.join(dirname, 'lehd_od_tracts_high_migration.csv')
data_agg.to_csv(outfile, columns=['trct', 'cty', 'S000'], index=False, encoding="utf-8")

# %% [markdown]
# ## Determine which census tracts have the highest number of jobs that people commute to from another county including greater bay area.

# %%
# greater bay area counties
cty_fips_list = [6001, 6013, 6041, 6047, 6055, 6067, 6069, 6075, 6077, 6081, 6085, 6087, 6095, 6097, 6099]

# %%
# sf bay area counties
target_cty_fips_list = [6001, 6013, 6041, 6055, 6075, 6081, 6085, 6095, 6097]

# %%
# filter rows in crosswalk to include only SF Bay counties and fields we need
cxwalk = cxwalk[cxwalk['cty'].isin(cty_fips_list)]
cxwalk = cxwalk[['trct', 'tabblk2010', 'cty', 'ctyname']]

# %%
data_h = lodes.merge(cxwalk, how="inner", left_on="h_geocode", right_on="tabblk2010")

# %%
# create seperate home and work county fips columns as strings to compare with one another
data_h['cty_h'] = data_h['h_geocode'].apply(str).str.slice(0,4)
data_h['cty_w'] = data_h['w_geocode'].apply(str).str.slice(0,4)
data_h['cty_h'] = pd.to_numeric(data_h['cty_h'], errors='coerce')
data_h['cty_w'] = pd.to_numeric(data_h['cty_w'], errors='coerce')

# %%
# inspect data
data_h.head(10)
# data_h.dtypes
# Out:
#         w_geocode       h_geocode  S000  SA01  SA02  SA03  SE01  SE02  SE03  \
# 0  60014001001007  60014003004007     1     0     1     0     0     0     1
# 1  60014003003017  60014003004007     1     0     0     1     0     1     0
# 2  60014003003018  60014003004007     1     1     0     0     0     1     0
# 3  60014003004011  60014003004007     1     0     1     0     1     0     0
# 4  60014010001002  60014003004007     1     1     0     0     0     0     1
# 5  60014011004018  60014003004007     1     1     0     0     1     0     0
# 6  60014028001007  60014003004007     1     1     0     0     0     1     0
# 7  60014028002035  60014003004007     1     0     0     1     0     0     1
# 8  60014030001002  60014003004007     1     0     0     1     0     0     1
# 9  60014033001008  60014003004007     1     0     1     0     0     1     0
#
#    SI01  SI02  SI03  createdate        trct      tabblk2010   cty  \
# 0     0     0     1    20190826  6001400300  60014003004007  6001
# 1     0     1     0    20190826  6001400300  60014003004007  6001
# 2     1     0     0    20190826  6001400300  60014003004007  6001
# 3     0     0     1    20190826  6001400300  60014003004007  6001
# 4     0     0     1    20190826  6001400300  60014003004007  6001
# 5     0     0     1    20190826  6001400300  60014003004007  6001
# 6     0     0     1    20190826  6001400300  60014003004007  6001
# 7     0     0     1    20190826  6001400300  60014003004007  6001
# 8     0     1     0    20190826  6001400300  60014003004007  6001
# 9     0     0     1    20190826  6001400300  60014003004007  6001
#
#               ctyname  cty_h  cty_w
# 0  Alameda County, CA   6001   6001
# 1  Alameda County, CA   6001   6001
# 2  Alameda County, CA   6001   6001
# 3  Alameda County, CA   6001   6001
# 4  Alameda County, CA   6001   6001
# 5  Alameda County, CA   6001   6001
# 6  Alameda County, CA   6001   6001
# 7  Alameda County, CA   6001   6001
# 8  Alameda County, CA   6001   6001
# 9  Alameda County, CA   6001   6001

# %%
# aggregate blocks to tracts while computing the number of local and away jobs per tract
data_agg = data_h.groupby(['trct', 'cty'], as_index=False).apply(lambda x: pd.Series(dict(
    sum_local=(x.cty_h == x.cty_w).sum(),
    sum_away=((x.cty_h != x.cty_w) & x.cty_w.isin(target_cty_fips_list)).sum() # only counting away as different from home county and within the 9 county bay area
)))

# %%
# compute proportion of away vs local
data_agg['ratio_away_to_local'] = data_agg['sum_away'] / data_agg['sum_local']

# %%
# sort by ratio column descending
data_agg = data_agg.sort_values('ratio_away_to_local', ascending=False)

# %%
# inspect the data
data_agg
# Out:
#                  sum_local  sum_away  ratio_away_to_local
# trct       cty
# 6095253000 6095         27       634            23.481481
# 6041122000 6041         21       388            18.476190
# 6041990100 6041         12       141            11.750000
# 6055200900 6055         23       193             8.391304
# 6081990100 6081         23       137             5.956522
# ...                    ...       ...                  ...
# 6085512312 6085       1064       231             0.217105
# 6085502907 6085       1536       327             0.212891
# 6085512311 6085       1241       263             0.211926
# 6085512305 6085       1407       283             0.201137
# 6085500800 6085       1377       245             0.177923
#
# [1588 rows x 3 columns]

# %%
# write processed data to csv file
outfile = os.path.join(dirname, 'lehd_od_tracts_home_ratio_gba.csv')
data_agg.to_csv(outfile, encoding="utf-8")

# %% [markdown]
# # Now we shall determine which tracts have the highest number of jobs that people commute daily

# %%
# aggregate blocks to tracts and sum S000 column
data_agg = data_h.groupby(['trct', 'cty'], as_index=False).apply(lambda x: pd.Series(dict(
    sum_local=(x.cty_h == x.cty_w).sum(),
    sum_away=(x.cty_h != x.cty_w).sum()
)))

# %%
# compute proportion of away vs local
data_agg['ratio_away_to_local'] = data_agg['sum_away'] / data_agg['sum_local']

# %%
# sort by ratio column descending
data_agg = data_agg.sort_values('ratio_away_to_local', ascending=False)

# %%
data_agg.head(10)
# Out:
#                  sum_local  sum_away  ratio_away_to_local
# trct       cty
# 6095253000 6095         27      1096            40.592593
# 6041122000 6041         21       560            26.666667
# 6041990100 6041         12       141            11.750000
# 6055200900 6055         23       270            11.739130
# 6095252802 6095         42       320             7.619048
# 6081990100 6081         23       138             6.000000
# 6013389100 6013        154       914             5.935065
# 6013391000 6013        173       944             5.456647
# 6013389200 6013        143       746             5.216783
# 6013355117 6013        503      2511             4.992048

# %%
# write processed data to csv file
outfile = os.path.join(dirname, 'lehd_od_tracts_home_ratio.csv')
data_agg.to_csv(outfile, encoding="utf-8")

# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-58-a62d01c1d62e> in <module>
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
lodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14713690 entries, 0 to 14713689
# Data columns (total 13 columns):
# w_geocode     int64
# h_geocode     int64
# S000          int64
# SA01          int64
# SA02          int64
# SA03          int64
# SE01          int64
# SE02          int64
# SE03          int64
# SI01          int64
# SI02          int64
# SI03          int64
# createdate    int64
# dtypes: int64(13)
# memory usage: 1.4 GB

# %%
lodes.head()
# Out:
#          w_geocode        h_geocode  S000  SA01  SA02  SA03  SE01  SE02  SE03  \
# 0  060014001001007  060014003004007     1     0     1     0     0     0     1
# 1  060014001001007  060014027002024     1     1     0     0     0     0     1
# 2  060014001001007  060014037011000     1     0     1     0     0     0     1
# 3  060014001001007  060014042001011     1     0     1     0     0     0     1
# 4  060014001001007  060014042003000     1     0     1     0     0     0     1
#
#    SI01  SI02  SI03  createdate
# 0     0     0     1    20190826
# 1     0     0     1    20190826
# 2     0     0     1    20190826
# 3     0     0     1    20190826
# 4     0     0     1    20190826

# %%
# extract home and work tract fips codes from the block fips codes
lodes['h_tract'] = lodes['h_geocode'].map(lambda x: x[0:11])
lodes['w_tract'] = lodes['w_geocode'].map(lambda x: x[0:11])

# %%
# how many workers commute from each tract
leave_from = lodes.groupby('h_tract')['S000'].sum()

# %%
# how many workers commute to each tract
travel_to = lodes.groupby('w_tract')['S000'].sum()

# %%
# verify that the counts match up
leave_from.sum() == travel_to.sum()
# Out:
# True

# %%
# create df indexed by tract with columns for number of workers leaving from and commuting to
commutes = pd.DataFrame(data={'travel_to':travel_to, 'leave_from':leave_from})
len(commutes)
# Out:
# 8057

# %%
commutes.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cfd1682edaed> in <module>
# ----> 1 commutes.head()
#
# NameError: name 'commutes' is not defined
